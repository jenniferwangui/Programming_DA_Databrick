# %%
df = spark.read.csv("FileStore/tables/Project/500_Cities-12468.csv",
                   header=True, sep=',', inferSchema=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">2</span><span class="ansired">]: </span>
# [&apos;Year&apos;,
#  &apos;StateAbbr&apos;,
#  &apos;StateDesc&apos;,
#  &apos;CityName&apos;,
#  &apos;GeographicLevel&apos;,
#  &apos;DataSource&apos;,
#  &apos;Category&apos;,
#  &apos;UniqueID&apos;,
#  &apos;Measure&apos;,
#  &apos;Data_Value_Unit&apos;,
#  &apos;DataValueTypeID&apos;,
#  &apos;Data_Value_Type&apos;,
#  &apos;Data_Value&apos;,
#  &apos;Low_Confidence_Limit&apos;,
#  &apos;High_Confidence_Limit&apos;,
#  &apos;Data_Value_Footnote_Symbol&apos;,
#  &apos;Data_Value_Footnote&apos;,
#  &apos;PopulationCount&apos;,
#  &apos;GeoLocation&apos;,
#  &apos;CategoryID&apos;,
#  &apos;MeasureId&apos;,
#  &apos;CityFIPS&apos;,
#  &apos;TractFIPS&apos;,
#  &apos;Short_Question_Text&apos;]
# </div>

# %%
#couldnot show the whole data due to memory issues
df.show(df.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">---------------------------------------------------------------------------</span>
# <span class="ansired">Py4JJavaError</span>                             Traceback (most recent call last)
# <span class="ansigreen">&lt;command-1182266022773712&gt;</span> in <span class="ansicyan">&lt;module&gt;</span><span class="ansiblue">()</span>
# <span class="ansigreen">----&gt; 1</span><span class="ansiyellow"> </span>df<span class="ansiyellow">.</span>show<span class="ansiyellow">(</span>df<span class="ansiyellow">.</span>count<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow">,</span> <span class="ansigreen">False</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/dataframe.py</span> in <span class="ansicyan">show</span><span class="ansiblue">(self, n, truncate, vertical)</span>
# <span class="ansigreen">    379</span>             print<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>_jdf<span class="ansiyellow">.</span>showString<span class="ansiyellow">(</span>n<span class="ansiyellow">,</span> <span class="ansicyan">20</span><span class="ansiyellow">,</span> vertical<span class="ansiyellow">)</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    380</span>         <span class="ansigreen">else</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 381</span><span class="ansiyellow">             </span>print<span class="ansiyellow">(</span>self<span class="ansiyellow">.</span>_jdf<span class="ansiyellow">.</span>showString<span class="ansiyellow">(</span>n<span class="ansiyellow">,</span> int<span class="ansiyellow">(</span>truncate<span class="ansiyellow">)</span><span class="ansiyellow">,</span> vertical<span class="ansiyellow">)</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">    382</span> <span class="ansiyellow"></span>
# <span class="ansigreen">    383</span>     <span class="ansigreen">def</span> __repr__<span class="ansiyellow">(</span>self<span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py</span> in <span class="ansicyan">__call__</span><span class="ansiblue">(self, *args)</span>
# <span class="ansigreen">   1255</span>         answer <span class="ansiyellow">=</span> self<span class="ansiyellow">.</span>gateway_client<span class="ansiyellow">.</span>send_command<span class="ansiyellow">(</span>command<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">   1256</span>         return_value = get_return_value(
# <span class="ansigreen">-&gt; 1257</span><span class="ansiyellow">             answer, self.gateway_client, self.target_id, self.name)
# </span><span class="ansigreen">   1258</span> <span class="ansiyellow"></span>
# <span class="ansigreen">   1259</span>         <span class="ansigreen">for</span> temp_arg <span class="ansigreen">in</span> temp_args<span class="ansiyellow">:</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansicyan">deco</span><span class="ansiblue">(*a, **kw)</span>
# <span class="ansigreen">     61</span>     <span class="ansigreen">def</span> deco<span class="ansiyellow">(</span><span class="ansiyellow">*</span>a<span class="ansiyellow">,</span> <span class="ansiyellow">**</span>kw<span class="ansiyellow">)</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">     62</span>         <span class="ansigreen">try</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">---&gt; 63</span><span class="ansiyellow">             </span><span class="ansigreen">return</span> f<span class="ansiyellow">(</span><span class="ansiyellow">*</span>a<span class="ansiyellow">,</span> <span class="ansiyellow">**</span>kw<span class="ansiyellow">)</span><span class="ansiyellow"></span>
# <span class="ansigreen">     64</span>         <span class="ansigreen">except</span> py4j<span class="ansiyellow">.</span>protocol<span class="ansiyellow">.</span>Py4JJavaError <span class="ansigreen">as</span> e<span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">     65</span>             s <span class="ansiyellow">=</span> e<span class="ansiyellow">.</span>java_exception<span class="ansiyellow">.</span>toString<span class="ansiyellow">(</span><span class="ansiyellow">)</span><span class="ansiyellow"></span>
#
# <span class="ansigreen">/databricks/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py</span> in <span class="ansicyan">get_return_value</span><span class="ansiblue">(answer, gateway_client, target_id, name)</span>
# <span class="ansigreen">    326</span>                 raise Py4JJavaError(
# <span class="ansigreen">    327</span>                     <span class="ansiblue">&quot;An error occurred while calling {0}{1}{2}.\n&quot;</span><span class="ansiyellow">.</span><span class="ansiyellow"></span>
# <span class="ansigreen">--&gt; 328</span><span class="ansiyellow">                     format(target_id, &quot;.&quot;, name), value)
# </span><span class="ansigreen">    329</span>             <span class="ansigreen">else</span><span class="ansiyellow">:</span><span class="ansiyellow"></span>
# <span class="ansigreen">    330</span>                 raise Py4JError(
#
# <span class="ansired">Py4JJavaError</span>: An error occurred while calling o224.showString.
# : java.lang.OutOfMemoryError: Java heap space
# 	at java.util.Arrays.copyOf(Arrays.java:3332)
# 	at java.lang.AbstractStringBuilder.ensureCapacityInternal(AbstractStringBuilder.java:124)
# 	at java.lang.AbstractStringBuilder.append(AbstractStringBuilder.java:448)
# 	at java.lang.StringBuilder.append(StringBuilder.java:136)
# 	at scala.collection.mutable.StringBuilder.append(StringBuilder.scala:200)
# 	at scala.collection.TraversableOnce$$anonfun$addString$1.apply(TraversableOnce.scala:364)
# 	at scala.collection.mutable.ResizableArray$class.foreach(ResizableArray.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:48)
# 	at scala.collection.TraversableOnce$class.addString(TraversableOnce.scala:357)
# 	at scala.collection.AbstractTraversable.addString(Traversable.scala:104)
# 	at org.apache.spark.sql.Dataset$$anonfun$showString$2.apply(Dataset.scala:341)
# 	at org.apache.spark.sql.Dataset$$anonfun$showString$2.apply(Dataset.scala:341)
# 	at scala.collection.mutable.ArraySeq.foreach(ArraySeq.scala:74)
# 	at org.apache.spark.sql.Dataset.showString(Dataset.scala:341)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:380)
# 	at py4j.Gateway.invoke(Gateway.java:295)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:251)
# 	at java.lang.Thread.run(Thread.java:748)
# </div>

# %%
df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">3</span><span class="ansired">]: </span>810103
# </div>

# %%
len(df.columns)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">4</span><span class="ansired">]: </span>24
# </div>

# %%
df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+---------+-------------+--------+---------------+----------+-------------------+--------+--------------------+---------------+---------------+--------------------+----------+--------------------+---------------------+--------------------------+-------------------+---------------+-----------+----------+---------+--------+---------+-------------------+
# Year|StateAbbr|    StateDesc|CityName|GeographicLevel|DataSource|           Category|UniqueID|             Measure|Data_Value_Unit|DataValueTypeID|     Data_Value_Type|Data_Value|Low_Confidence_Limit|High_Confidence_Limit|Data_Value_Footnote_Symbol|Data_Value_Footnote|PopulationCount|GeoLocation|CategoryID|MeasureId|CityFIPS|TractFIPS|Short_Question_Text|
# +----+---------+-------------+--------+---------------+----------+-------------------+--------+--------------------+---------------+---------------+--------------------+----------+--------------------+---------------------+--------------------------+-------------------+---------------+-----------+----------+---------+--------+---------+-------------------+
# 2016|       US|United States|    null|             US|     BRFSS|         Prevention|      59|Current lack of h...|              %|      AgeAdjPrv|Age-adjusted prev...|      14.6|                14.3|                 14.9|                      null|               null|      308745538|       null|   PREVENT|  ACCESS2|    null|     null|   Health Insurance|
# 2016|       US|United States|    null|             US|     BRFSS|         Prevention|      59|Current lack of h...|              %|         CrdPrv|    Crude prevalence|      11.6|                11.3|                 11.8|                      null|               null|      308745538|       null|   PREVENT|  ACCESS2|    null|     null|   Health Insurance|
# 2016|       US|United States|    null|             US|     BRFSS|    Health Outcomes|      59|Arthritis among a...|              %|      AgeAdjPrv|Age-adjusted prev...|      23.0|                22.8|                 23.2|                      null|               null|      308745538|       null|   HLTHOUT|ARTHRITIS|    null|     null|          Arthritis|
# 2016|       US|United States|    null|             US|     BRFSS|    Health Outcomes|      59|Arthritis among a...|              %|         CrdPrv|    Crude prevalence|      25.4|                25.1|                 25.6|                      null|               null|      308745538|       null|   HLTHOUT|ARTHRITIS|    null|     null|          Arthritis|
# 2016|       US|United States|    null|             US|     BRFSS|Unhealthy Behaviors|      59|Binge drinking am...|              %|      AgeAdjPrv|Age-adjusted prev...|      18.0|                17.7|                 18.2|                      null|               null|      308745538|       null|    UNHBEH|    BINGE|    null|     null|     Binge Drinking|
# +----+---------+-------------+--------+---------------+----------+-------------------+--------+--------------------+---------------+---------------+--------------------+----------+--------------------+---------------------+--------------------------+-------------------+---------------+-----------+----------+---------+--------+---------+-------------------+
# only showing top 5 rows
#
# </div>

# %%
df.describe("Category").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------------+
# summary|           Category|
# +-------+-------------------+
#   count|             810103|
#    mean|               null|
#  stddev|               null|
#     min|    Health Outcomes|
#     max|Unhealthy Behaviors|
# +-------+-------------------+
#
# </div>

# %%
df.describe("Measure").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------------------+
# summary|             Measure|
# +-------+--------------------+
#   count|              810103|
#    mean|                null|
#  stddev|                null|
#     min|All teeth lost am...|
#     max|Visits to doctor ...|
# +-------+--------------------+
#
# </div>

# %%
df.describe("CategoryID").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+----------+
# summary|CategoryID|
# +-------+----------+
#   count|    810103|
#    mean|      null|
#  stddev|      null|
#     min|   HLTHOUT|
#     max|    UNHBEH|
# +-------+----------+
#
# </div>

# %%
df.describe("PopulationCount").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+
# summary|   PopulationCount|
# +-------+------------------+
#   count|            810103|
#    mean|32024.127319612446|
#  stddev| 2568489.096876524|
#     min|                 1|
#     max|         308745538|
# +-------+------------------+
#
# </div>

# %%
df.select("MeasureID", "CategoryID").distinct().show(df.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+----------+
# MeasureID   |CategoryID|
# +------------+----------+
# LPA         |UNHBEH    |
# COLON_SCREEN|PREVENT   |
# BPMED       |PREVENT   |
# CSMOKING    |UNHBEH    |
# OBESITY     |UNHBEH    |
# BINGE       |UNHBEH    |
# CHECKUP     |PREVENT   |
# TEETHLOST   |HLTHOUT   |
# DENTAL      |PREVENT   |
# PHLTH       |HLTHOUT   |
# CANCER      |HLTHOUT   |
# CHOLSCREEN  |PREVENT   |
# STROKE      |HLTHOUT   |
# COREW       |PREVENT   |
# BPHIGH      |HLTHOUT   |
# MAMMOUSE    |PREVENT   |
# COPD        |HLTHOUT   |
# DIABETES    |HLTHOUT   |
# MHLTH       |HLTHOUT   |
# HIGHCHOL    |HLTHOUT   |
# KIDNEY      |HLTHOUT   |
# PAPTEST     |PREVENT   |
# COREM       |PREVENT   |
# ACCESS2     |PREVENT   |
# ARTHRITIS   |HLTHOUT   |
# SLEEP       |UNHBEH    |
# CHD         |HLTHOUT   |
# CASTHMA     |HLTHOUT   |
# +------------+----------+
#
# </div>

# %%
df2 = df.select("Year", "StateDesc", "Category", "Measure", "Data_Value_Type", "MeasureId")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df2.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------------+-------------------+--------------------+--------------------+---------+
# Year|    StateDesc|           Category|             Measure|     Data_Value_Type|MeasureId|
# +----+-------------+-------------------+--------------------+--------------------+---------+
# 2016|United States|         Prevention|Current lack of h...|Age-adjusted prev...|  ACCESS2|
# 2016|United States|         Prevention|Current lack of h...|    Crude prevalence|  ACCESS2|
# 2016|United States|    Health Outcomes|Arthritis among a...|Age-adjusted prev...|ARTHRITIS|
# 2016|United States|    Health Outcomes|Arthritis among a...|    Crude prevalence|ARTHRITIS|
# 2016|United States|Unhealthy Behaviors|Binge drinking am...|Age-adjusted prev...|    BINGE|
# +----+-------------+-------------------+--------------------+--------------------+---------+
# only showing top 5 rows
#
# </div>

# %%
#More records on health outcomes on 2016 than 2015
df2.filter(df.Category == 'Health Outcomes').groupBy("Year").count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+------+
# Year| count|
# +----+------+
# 2015| 58012|
# 2016|318661|
# +----+------+
#
# </div>

# %%
#Filtering rows that we need for analysis

DF4 = df2.filter( (df2["Data_Value_Type"] == "Crude prevalence") & (df2["StateDesc"] != "United States"))
DF4.show(DF4.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------------+-------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+------------+
# Year|StateDesc    |Category           |Measure                                                                                                                                                                                       |Data_Value_Type |MeasureId   |
# +----+-------------+-------------------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----------------+------------+
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years                                                                                                                                |Crude prevalence|ACCESS2     |
# 2016|Alabama      |Prevention         |Current lack of health insurance among adults aged 18–64 Years

# %%
DF4.filter(df.Category.isNull()).count()
#DF4.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">182</span><span class="ansired">]: </span>0
# </div>

# %%
DF4.filter(df.Measure.isNull()).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">183</span><span class="ansired">]: </span>0
# </div>

# %%
#Total number of chronic illness(Health outcomes) recorded in each state in 2015
D = DF4.filter( (DF4["Year"] == "2015") & (DF4["Category"] == "Health Outcomes")).groupBy("StateDesc").count()
D.show(D.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+-----+
# StateDesc    |count|
# +-------------+-----+
# Utah         |516  |
# Hawaii       |480  |
# North Carolin|1648 |
# Minnesota    |638  |
# Ohio         |1708 |
# Arkansas     |254  |
# Oregon       |730  |
# South Carolin|358  |
# Texas        |6324 |
# North Dakota |52   |
# Pennsylvania |1302 |
# Connecticut  |456  |
# Nebraska     |442  |
# Vermont      |24   |
# Nevada       |752  |
# Washington   |1078 |
# Illinois     |2642 |
# Oklahoma     |956  |
# Delaware     |50   |
# Alaska       |112  |
# District of C|360  |
# New Mexico   |442  |
# West Virginia|50   |
# Missouri     |918  |
# Rhode Island |206  |
# Georgia      |926  |
# Montana      |92   |
# Michigan     |1520 |
# Virginia     |1024 |
# Wyoming      |34   |
# Kansas       |626  |
# New Jersey   |626  |
# Maryland     |402  |
# Alabama      |748  |
# Arizona      |2102 |
# Iowa         |410  |
# Massachusetts|1000 |
# Kentucky     |534  |
# Louisiana    |766  |
# Mississippi  |156  |
# New Hampshire|98   |
# Tennessee    |1086 |
# Florida      |2728 |
# Indiana      |1072 |
# Idaho        |142  |
# South Dakota |122  |
# California   |10978|
# New York     |4998 |
# Wisconsin    |834  |
# Colorado     |1444 |
# Maine        |42   |
# +-------------+-----+
#
# </div>

# %%
# All cases of chronic diseases recorded in each state 2015 and 2016
DF10 = DF4.filter(DF4.Category == 'Health Outcomes').groupBy("StateDesc", "Year").count()
DF10.show(DF10.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+----+-----+
# StateDesc    |Year|count|
# +-------------+----+-----+
# Maryland     |2016|2211 |
# Hawaii       |2016|2634 |
# Nevada       |2015|752  |
# Alaska       |2016|616  |
# Alaska       |2015|112  |
# Louisiana    |2016|4211 |
# Rhode Island |2015|206  |
# Tennessee    |2015|1086 |
# New Hampshire|2016|539  |
# New Mexico   |2016|2425 |
# Indiana      |2016|5889 |
# Kansas       |2016|3439 |
# Kansas       |2015|626  |
# Missouri     |2015|918  |
# Arkansas     |2016|1395 |
# District of C|2016|1979 |
# District of C|2015|360  |
# Delaware     |2016|275  |
# Alabama      |2015|748  |
# Massachusetts|2016|5496 |
# Mississippi  |2015|156  |
# Arizona      |2016|11546|
# Vermont      |2015|24   |
# Wisconsin    |2015|834  |
# Utah         |2016|2832 |
# Texas        |2015|6324 |
# South Dakota |2015|122  |
# Mississippi  |2016|857  |
# Massachusetts|2015|1000 |
# Oklahoma     |2016|5254 |
# Oregon       |2016|4005 |
# South Carolin|2015|358  |
# Utah         |2015|516  |
# New Jersey   |2016|3443 |
# North Carolin|2015|1648 |
# North Dakota |2015|52   |
# Michigan     |2015|1520 |
# Minnesota    |2016|3508 |
# New Jersey   |2015|626  |
# New York     |2015|4998 |
# New Hampshire|2015|98   |
# Wisconsin    |2016|4584 |
# New Mexico   |2015|442  |
# Ohio         |2016|9383 |
# West Virginia|2015|50   |
# Virginia     |2015|1024 |
# Arizona      |2015|2102 |
# Connecticut  |2016|2507 |
# Delaware     |2015|50   |
# Hawaii       |2015|480  |
# Missouri     |2016|5039 |
# North Carolin|2016|9031 |
# North Dakota |2016|286  |
# Florida      |2016|14989|
# Pennsylvania |2015|1302 |
# Oklahoma     |2015|956  |
# Pennsylvania |2016|7155 |
# California   |2016|60324|
# Wyoming      |2015|34   |
# Colorado     |2015|1444 |
# Iowa         |2016|2250 |
# Maine        |2015|42   |
# Alabama      |2016|4105 |
# Washington   |2015|1078 |
# Rhode Island |2016|1132 |
# Indiana      |2015|1072 |
# Ohio         |2015|1708 |
# New York     |2016|27471|
# Nevada       |2016|4130 |
# Vermont      |2016|132  |
# Montana      |2015|92   |
# Michigan     |2016|8348 |
# Kentucky     |2015|534  |
# Nebraska     |2016|2426 |
# Arkansas     |2015|254  |
# Connecticut  |2015|456  |
# Georgia      |2016|5088 |
# Minnesota    |2015|638  |
# Tennessee    |2016|5958 |
# South Dakota |2016|670  |
# Iowa         |2015|410  |
# Maryland     |2015|402  |
# South Carolin|2016|1965 |
# Maine        |2016|231  |
# California   |2015|10978|
# Oregon       |2015|730  |
# Virginia     |2016|5630 |
# Colorado     |2016|7927 |
# Washington   |2016|5923 |
# Georgia      |2015|926  |
# Idaho        |2016|781  |
# Idaho        |2015|142  |
# Montana      |2016|505  |
# Illinois     |2015|2642 |
# Kentucky     |2016|2936 |
# Illinois     |2016|14525|
# Texas        |2016|34692|
# Louisiana    |2015|766  |
# Nebraska     |2015|442  |
# Florida      |2015|2728 |
# Wyoming      |2016|187  |
# West Virginia|2016|275  |
# +-------------+----+-----+
#
# </div>

# %%
 DF12.count()
 DF10.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">44</span><span class="ansired">]: </span>102
# </div>

# %%
#join not possible due to unequal number of rows in dataframes
DF10.join(DF12, DF10.Year == DF12.Year).select(DF10["*"],DF12["count"]).show()

#df1.join(df2, df1.id == df2.id).select(df1["*"],df2["other"])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+----+-----+-----+
# StateDesc|Year|count|count|
# +---------+----+-----+-----+
#  Maryland|2016| 2211| 1005|
#  Maryland|2016| 2211| 1200|
#  Maryland|2016| 2211|  280|
#  Maryland|2016| 2211| 1915|
#  Maryland|2016| 2211|  245|
#  Maryland|2016| 2211| 1105|
#  Maryland|2016| 2211| 2680|
#  Maryland|2016| 2211| 1565|
#  Maryland|2016| 2211|  635|
#  Maryland|2016| 2211|  900|
#  Maryland|2016| 2211|  125|
#  Maryland|2016| 2211| 2500|
#  Maryland|2016| 2211| 5255|
#  Maryland|2016| 2211| 1290|
#  Maryland|2016| 2211|  390|
#  Maryland|2016| 2211| 2390|
#  Maryland|2016| 2211| 1825|
#  Maryland|2016| 2211| 1565|
#  Maryland|2016| 2211| 1595|
#  Maryland|2016| 2211| 2085|
# +---------+----+-----+-----+
# only showing top 20 rows
#
# </div>

# %%
# all health outcomes 2015 and 2016
DF6 = DF4.filter(DF4.Category == 'Health Outcomes').groupBy("StateDesc").count()
DF6.show(DF6.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+-----+
# StateDesc    |count|
# +-------------+-----+
# Utah         |3348 |
# Hawaii       |3114 |
# North Carolin|10679|
# Minnesota    |4146 |
# Ohio         |11091|
# Arkansas     |1649 |
# Oregon       |4735 |
# South Carolin|2323 |
# Texas        |41016|
# North Dakota |338  |
# Pennsylvania |8457 |
# Connecticut  |2963 |
# Nebraska     |2868 |
# Vermont      |156  |
# Nevada       |4882 |
# Washington   |7001 |
# Illinois     |17167|
# Oklahoma     |6210 |
# Delaware     |325  |
# Alaska       |728  |
# District of C|2339 |
# New Mexico   |2867 |
# West Virginia|325  |
# Missouri     |5957 |
# Rhode Island |1338 |
# Georgia      |6014 |
# Montana      |597  |
# Michigan     |9868 |
# Virginia     |6654 |
# Wyoming      |221  |
# Kansas       |4065 |
# New Jersey   |4069 |
# Maryland     |2613 |
# Alabama      |4853 |
# Arizona      |13648|
# Iowa         |2660 |
# Massachusetts|6496 |
# Kentucky     |3470 |
# Louisiana    |4977 |
# Mississippi  |1013 |
# New Hampshire|637  |
# Tennessee    |7044 |
# Florida      |17717|
# Indiana      |6961 |
# Idaho        |923  |
# South Dakota |792  |
# California   |71302|
# New York     |32469|
# Wisconsin    |5418 |
# Colorado     |9371 |
# Maine        |273  |
# +-------------+-----+
#
# </div>

# %%
dft2 = DF12.filter(DF12['Year'] == '2016')
dft2.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+----+-----+
#     StateDesc|Year|count|
# +-------------+----+-----+
#      Maryland|2016| 1005|
#        Hawaii|2016| 1200|
#        Alaska|2016|  280|
#     Louisiana|2016| 1915|
# New Hampshire|2016|  245|
#    New Mexico|2016| 1105|
#       Indiana|2016| 2680|
#        Kansas|2016| 1565|
#      Arkansas|2016|  635|
# District of C|2016|  900|
#      Delaware|2016|  125|
# Massachusetts|2016| 2500|
#       Arizona|2016| 5255|
#          Utah|2016| 1290|
#   Mississippi|2016|  390|
#      Oklahoma|2016| 2390|
#        Oregon|2016| 1825|
#    New Jersey|2016| 1565|
#     Minnesota|2016| 1595|
#     Wisconsin|2016| 2085|
# +-------------+----+-----+
# only showing top 20 rows
#
# </div>

# %%
DF12 = DF4.filter(DF4.Category == 'Unhealthy Behaviors').groupBy("StateDesc", "Year").count()
DF12.show(DF12.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+----+-----+
# StateDesc    |Year|count|
# +-------------+----+-----+
# Maryland     |2016|1005 |
# Hawaii       |2016|1200 |
# Alaska       |2016|280  |
# Louisiana    |2016|1915 |
# New Hampshire|2016|245  |
# New Mexico   |2016|1105 |
# Indiana      |2016|2680 |
# Kansas       |2016|1565 |
# Arkansas     |2016|635  |
# District of C|2016|900  |
# Delaware     |2016|125  |
# Massachusetts|2016|2500 |
# Arizona      |2016|5255 |
# Utah         |2016|1290 |
# Mississippi  |2016|390  |
# Oklahoma     |2016|2390 |
# Oregon       |2016|1825 |
# New Jersey   |2016|1565 |
# Minnesota    |2016|1595 |
# Wisconsin    |2016|2085 |
# Ohio         |2016|4270 |
# Connecticut  |2016|1140 |
# Missouri     |2016|2295 |
# North Carolin|2016|4120 |
# North Dakota |2016|130  |
# Florida      |2016|6820 |
# Pennsylvania |2016|3255 |
# California   |2016|27445|
# Iowa         |2016|1025 |
# Alabama      |2016|1870 |
# Rhode Island |2016|515  |
# New York     |2016|12495|
# Nevada       |2016|1880 |
# Vermont      |2016|60   |
# Michigan     |2016|3800 |
# Nebraska     |2016|1105 |
# Georgia      |2016|2315 |
# Tennessee    |2016|2715 |
# South Dakota |2016|305  |
# South Carolin|2016|895  |
# Maine        |2016|105  |
# Virginia     |2016|2560 |
# Colorado     |2016|3610 |
# Washington   |2016|2695 |
# Idaho        |2016|355  |
# Montana      |2016|230  |
# Kentucky     |2016|1335 |
# Illinois     |2016|6605 |
# Texas        |2016|15810|
# Wyoming      |2016|85   |
# West Virginia|2016|125  |
# +-------------+----+-----+
#
# </div>

# %%
DF10.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">30</span><span class="ansired">]: </span>102
# </div>

# %%
df11 = DF12.withColumnRenamed('count', 'unhealthycount')
df11.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+----+--------------+
#     StateDesc|Year|unhealthycount|
# +-------------+----+--------------+
#      Maryland|2016|          1005|
#        Hawaii|2016|          1200|
#        Alaska|2016|           280|
#     Louisiana|2016|          1915|
# New Hampshire|2016|           245|
#    New Mexico|2016|          1105|
#       Indiana|2016|          2680|
#        Kansas|2016|          1565|
#      Arkansas|2016|           635|
# District of C|2016|           900|
#      Delaware|2016|           125|
# Massachusetts|2016|          2500|
#       Arizona|2016|          5255|
#          Utah|2016|          1290|
#   Mississippi|2016|           390|
#      Oklahoma|2016|          2390|
#        Oregon|2016|          1825|
#    New Jersey|2016|          1565|
#     Minnesota|2016|          1595|
#     Wisconsin|2016|          2085|
# +-------------+----+--------------+
# only showing top 20 rows
#
# </div>

# %%
DF11 = DF4.filter(DF4.Category == 'Prevention').groupBy("StateDesc", "Year").count()
DF11.show(DF11.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+----+-----+
# StateDesc    |Year|count|
# +-------------+----+-----+
# Maryland     |2016|1607 |
# Hawaii       |2016|1899 |
# Nevada       |2015|752  |
# Alaska       |2016|448  |
# Alaska       |2015|112  |
# Louisiana    |2016|3049 |
# Rhode Island |2015|206  |
# Tennessee    |2015|1086 |
# New Hampshire|2016|392  |
# New Mexico   |2016|1747 |
# Indiana      |2016|4260 |
# Kansas       |2016|2489 |
# Kansas       |2015|626  |
# Missouri     |2015|918  |
# Arkansas     |2016|1001 |
# District of C|2016|1438 |
# District of C|2015|360  |
# Delaware     |2016|200  |
# Alabama      |2015|748  |
# Massachusetts|2016|3986 |
# Mississippi  |2015|156  |
# Arizona      |2016|8337 |
# Vermont      |2015|24   |
# Wisconsin    |2015|834  |
# Utah         |2016|2025 |
# Texas        |2015|6324 |
# South Dakota |2015|122  |
# Mississippi  |2016|614  |
# Massachusetts|2015|1000 |
# Oklahoma     |2016|3808 |
# Oregon       |2016|2888 |
# South Carolin|2015|358  |
# Utah         |2015|516  |
# New Jersey   |2016|2501 |
# North Carolin|2015|1648 |
# North Dakota |2015|52   |
# Michigan     |2015|1520 |
# Minnesota    |2016|2548 |
# New Jersey   |2015|626  |
# New York     |2015|4998 |
# New Hampshire|2015|98   |
# Wisconsin    |2016|3316 |
# New Mexico   |2015|442  |
# Ohio         |2016|6790 |
# West Virginia|2015|50   |
# Virginia     |2015|1024 |
# Arizona      |2015|2102 |
# Connecticut  |2016|1820 |
# Delaware     |2015|50   |
# Hawaii       |2015|480  |
# Missouri     |2016|3634 |
# North Carolin|2016|6466 |
# North Dakota |2016|208  |
# Florida      |2016|10836|
# Pennsylvania |2015|1302 |
# Oklahoma     |2015|956  |
# Pennsylvania |2016|5182 |
# California   |2016|43665|
# Wyoming      |2015|34   |
# Colorado     |2015|1444 |
# Iowa         |2016|1626 |
# Maine        |2015|42   |
# Alabama      |2016|2954 |
# Washington   |2015|1078 |
# Rhode Island |2016|822  |
# Indiana      |2015|1072 |
# Ohio         |2015|1708 |
# New York     |2016|19919|
# Nevada       |2016|2985 |
# Vermont      |2016|96   |
# Montana      |2015|92   |
# Michigan     |2016|6036 |
# Kentucky     |2015|534  |
# Nebraska     |2016|1745 |
# Arkansas     |2015|254  |
# Connecticut  |2015|456  |
# Georgia      |2016|3688 |
# Minnesota    |2015|638  |
# Tennessee    |2016|4286 |
# South Dakota |2016|485  |
# Iowa         |2015|410  |
# Maryland     |2015|402  |
# South Carolin|2016|1415 |
# Maine        |2016|168  |
# California   |2015|10978|
# Oregon       |2015|730  |
# Virginia     |2016|4084 |
# Colorado     |2016|5732 |
# Washington   |2016|4282 |
# Georgia      |2015|926  |
# Idaho        |2016|566  |
# Idaho        |2015|142  |
# Montana      |2016|365  |
# Illinois     |2015|2642 |
# Kentucky     |2016|2132 |
# Illinois     |2016|10540|
# Texas        |2016|24956|
# Louisiana    |2015|766  |
# Nebraska     |2015|442  |
# Florida      |2015|2728 |
# Wyoming      |2016|136  |
# West Virginia|2016|200  |
# +-------------+----+-----+
#
# </div>

# %%
df1 = df2.groupBy("MeasureId").count()
df1.show(df1.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+-----+
# MeasureId   |count|
# +------------+-----+
# COREW       |28453|
# HIGHCHOL    |29006|
# SLEEP       |29006|
# ACCESS2     |28973|
# CHOLSCREEN  |29006|
# COREM       |28464|
# COPD        |29006|
# CANCER      |29006|
# BPMED       |29006|
# LPA         |29006|
# BPHIGH      |29006|
# DIABETES    |29006|
# OBESITY     |29006|
# CHD         |29006|
# COLON_SCREEN|28847|
# CSMOKING    |29006|
# MHLTH       |29006|
# ARTHRITIS   |29006|
# KIDNEY      |29006|
# CASTHMA     |29006|
# PAPTEST     |28912|
# MAMMOUSE    |28727|
# PHLTH       |29006|
# DENTAL      |29006|
# CHECKUP     |29006|
# BINGE       |29006|
# TEETHLOST   |28601|
# STROKE      |29006|
# +------------+-----+
#
# </div>

# %%
#df2.filter(df2.category == 'Unhealthy Behaviors').show()
df2.filter(df2.Category == 'Prevention').groupBy("Year").count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+------+
# Year| count|
# +----+------+
# 2015| 58012|
# 2016|230388|
# +----+------+
#
# </div>

# %%
d = df2.groupBy("MeasureId").count()
d.show(d.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+-----+
# MeasureId   |count|
# +------------+-----+
# COREW       |28453|
# HIGHCHOL    |29006|
# SLEEP       |29006|
# ACCESS2     |28973|
# CHOLSCREEN  |29006|
# COREM       |28464|
# COPD        |29006|
# CANCER      |29006|
# BPMED       |29006|
# LPA         |29006|
# BPHIGH      |29006|
# DIABETES    |29006|
# OBESITY     |29006|
# CHD         |29006|
# COLON_SCREEN|28847|
# CSMOKING    |29006|
# MHLTH       |29006|
# ARTHRITIS   |29006|
# KIDNEY      |29006|
# CASTHMA     |29006|
# PAPTEST     |28912|
# MAMMOUSE    |28727|
# PHLTH       |29006|
# DENTAL      |29006|
# CHECKUP     |29006|
# BINGE       |29006|
# TEETHLOST   |28601|
# STROKE      |29006|
# +------------+-----+
#
# </div>

# %%
#save file as csv.
#df.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("/filestore/Project/500_cities.csv")

# %%
#second dataset Death rate causes in USA
d = spark.read.csv("FileStore/tables/Project/NCHS___Leading_Causes_of_Death__United_States-87e5e.csv",
                   header=True, sep=',', inferSchema=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
d.show(d.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+---------------------------------------------------------------------+-----------------------+--------------------+-------+-----------------------+
# Year|113 Cause Name                                                       |Cause Name             |State               |Deaths |Age-adjusted Death Rate|
# +----+---------------------------------------------------------------------+-----------------------+--------------------+-------+-----------------------+
# 2012|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Vermont             |21     |2.6                    |
# 2016|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Vermont             |30     |3.7                    |
# 2013|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Vermont             |30     |3.8                    |
# 2000|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |District of Columbia|23     |3.8                    |
# 2014|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Arizona             |325    |4.1                    |
# 2009|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |District of Columbia|29     |4.4                    |
# 2011|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |South Dakota        |49     |4.5                    |
# 2015|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Vermont             |39     |4.5                    |
# 2014|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Vermont             |37     |4.5                    |
# 2013|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Arizona             |374    |4.9                    |
# 2015|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |District of Columbia|34     |4.9                    |
# 2001|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Washington          |279    |5.0                    |
# 1999|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |District of Columbia|30     |5.1                    |
# 1999|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Washington          |278    |5.2                    |
# 2016|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |District of Columbia|40     |5.2                    |
# 2006|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |District of Columbia|30     |5.2                    |
# 2002|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |District of Columbia|31     |5.2                    |
# 2003|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Washington          |304    |5.3                    |
# 2011|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Vermont             |43     |5.4                    |
# 2008|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Vermont             |39     |5.4                    |
# 2002|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Washington          |306    |5.4                    |
# 2000|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Washington          |293    |5.4                    |
# 2005|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |District of Columbia|33     |5.4                    |
# 2015|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Arizona             |458    |5.5                    |
# 2004|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |District of Columbia|33     |5.5                    |
# 2011|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Arizona             |395    |5.6                    |
# 2012|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |South Dakota        |58     |5.6                    |
# 2011|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |District of Columbia|37     |5.6                    |
# 2016|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Arizona             |487    |5.7                    |
# 2012|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Arizona             |414    |5.7                    |
# 2013|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |District of Columbia|38     |5.7                    |
# 2012|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |District of Columbia|37     |5.7                    |
# 2006|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Iowa                |225    |5.8                    |
# 2005|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |South Dakota        |55     |5.8                    |
# 2013|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |South Dakota        |64     |5.9                    |
# 2015|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Washington          |474    |5.9                    |
# 2004|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Washington          |348    |5.9                    |
# 2003|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |New York            |1169   |5.9                    |
# 2000|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |New York            |1132   |5.9                    |
# 2001|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Iowa                |220    |6.0                    |
# 2007|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |District of Columbia|36     |6.0                    |
# 2000|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |Massachusetts       |387    |6.0                    |
# 2005|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |New York            |1189   |6.0                    |
# 2004|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |New York            |1187   |6.0                    |
# 2013|Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)|Kidney disease         |Washington          |461    |6.1                    |
# 2003|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |District of Columbia|36     |6.1                    |
# 2005|Intentional self-harm (suicide) (*U03,X60-X84,Y87.0)                 |Suicide                |New Jersey          |536    |6.1                    |
# 2000|Nephritis, neph

# %%
d1 = d.select("Year", "Cause Name", "State", "Deaths")
d1.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------+--------------------+------+
# Year|    Cause Name|               State|Deaths|
# +----+--------------+--------------------+------+
# 2012|Kidney disease|             Vermont|    21|
# 2016|Kidney disease|             Vermont|    30|
# 2013|Kidney disease|             Vermont|    30|
# 2000|       Suicide|District of Columbia|    23|
# 2014|Kidney disease|             Arizona|   325|
# 2009|       Suicide|District of Columbia|    29|
# 2011|Kidney disease|        South Dakota|    49|
# 2015|Kidney disease|             Vermont|    39|
# 2014|Kidney disease|             Vermont|    37|
# 2013|Kidney disease|             Arizona|   374|
# 2015|       Suicide|District of Columbia|    34|
# 2001|Kidney disease|          Washington|   279|
# 1999|       Suicide|District of Columbia|    30|
# 1999|Kidney disease|          Washington|   278|
# 2016|       Suicide|District of Columbia|    40|
# 2006|       Suicide|District of Columbia|    30|
# 2002|       Suicide|District of Columbia|    31|
# 2003|Kidney disease|          Washington|   304|
# 2011|Kidney disease|             Vermont|    43|
# 2008|Kidney disease|             Vermont|    39|
# +----+--------------+--------------------+------+
# only showing top 20 rows
#
# </div>

# %%
d2 = d1.filter( (d1["Year"] == "2015") | (d1["Year"] == "2016"))
d2.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------------+--------------------+------+
# Year|          Cause Name|               State|Deaths|
# +----+--------------------+--------------------+------+
# 2016|      Kidney disease|             Vermont|    30|
# 2015|      Kidney disease|             Vermont|    39|
# 2015|             Suicide|District of Columbia|    34|
# 2016|             Suicide|District of Columbia|    40|
# 2015|      Kidney disease|             Arizona|   458|
# 2016|      Kidney disease|             Arizona|   487|
# 2015|      Kidney disease|          Washington|   474|
# 2016|      Kidney disease|          Washington|   532|
# 2016|Influenza and pne...|             Vermont|    59|
# 2016|             Suicide|          New Jersey|   687|
# 2015|      Kidney disease|        South Dakota|    79|
# 2016|      Kidney disease|        South Dakota|    90|
# 2016|      Kidney disease|              Oregon|   398|
# 2016|Influenza and pne...|           Minnesota|   529|
# 2015|             Suicide|            New York|  1652|
# 2015|      Kidney disease|                Iowa|   336|
# 2016|             Suicide|            New York|  1679|
# 2015|      Kidney disease|              Oregon|   409|
# 2016|      Kidney disease|                Iowa|   352|
# 2015|             Suicide|          New Jersey|   789|
# +----+--------------------+--------------------+------+
# only showing top 20 rows
#
# </div>

# %%
d3 = d2.filter((d2["Cause Name"] != "All causes") & (d2["State"] != "United States")) 
d3.show(d3.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----------------------+--------------------+------+
# Year|Cause Name             |State               |Deaths|
# +----+-----------------------+--------------------+------+
# 2016|Kidney disease         |Vermont             |30    |
# 2015|Kidney disease         |Vermont             |39    |
# 2015|Suicide                |District of Columbia|34    |
# 2016|Suicide                |District of Columbia|40    |
# 2015|Kidney disease         |Arizona             |458   |
# 2016|Kidney disease         |Arizona             |487   |
# 2015|Kidney disease         |Washington          |474   |
# 2016|Kidney disease         |Washington          |532   |
# 2016|Influenza and pneumonia|Vermont             |59    |
# 2016|Suicide                |New Jersey          |687   |
# 2015|Kidney disease         |South Dakota        |79    |
# 2016|Kidney disease         |South Dakota        |90    |
# 2016|Kidney disease         |Oregon              |398   |
# 2016|Influenza and pneumonia|Minnesota           |529   |
# 2015|Suicide                |New York            |1652  |
# 2015|Kidney disease         |Iowa                |336   |
# 2016|Suicide                |New York            |1679  |
# 2015|Kidney disease         |Oregon              |409   |
# 2016|Kidney disease         |Iowa                |352   |
# 2015|Suicide                |New Jersey          |789   |
# 2015|Influenza and pneumonia|Alaska              |41    |
# 2015|Kidney disease         |Colorado            |458   |
# 2016|Kidney disease         |California          |3640  |
# 2015|Kidney disease         |California          |3557  |
# 2015|Kidney disease         |Idaho               |154   |
# 2016|Kidney disease         |Minnesota           |588   |
# 2016|Kidney disease         |Nevada              |274   |
# 2015|Suicide                |Maryland            |553   |
# 2016|Suicide                |Massachusetts       |631   |
# 2015|Influenza and pneumonia|Florida             |2676  |
# 2016|Influenza and pneumonia|Oregon              |452   |
# 2016|Kidney disease         |Colorado            |491   |
# 2015|Suicide                |Massachusetts       |642   |
# 2015|Influenza and pneumonia|Oregon              |453   |
# 2016|Kidney disease         |District of Columbia|57    |
# 2016|Influenza and pneumonia|Florida             |2808  |
# 2015|Kidney disease         |Montana             |121   |
# 2015|Kidney disease         |New York            |2245  |
# 2016|Kidney disease         |New Hampshire       |161   |
# 2016|Suicide                |Maryland            |586   |
# 2015|Influenza and pneumonia|Arizona             |775   |
# 2016|Kidney disease         |Nebraska            |220   |
# 2016|Influenza and pneumonia|Colorado            |533   |
# 2015|Kidney disease         |Minnesota           |639   |
# 2016|Kidney disease         |New York            |2385  |
# 2015|Kidney disease         |Rhode Island        |142   |
# 2015|Kidney disease         |District of Columbia|65    |
# 2016|Kidney disease         |Rhode Island        |141   |
# 2015|Suicide                |Connecticut         |384   |
# 2015|Influenza and pneumonia|Vermont             |85    |
# 2016|Influenza and pneumonia|Washington          |815   |
# 2016|Kidney disease         |Alaska              |53    |
# 2015|Kidney disease         |Alaska              |50    |
# 2016|Kidney disease         |Wyoming             |66    |
# 2016|Suicide                |Connecticut         |397   |
# 2016|Kidney disease         |Florida             |3144  |
# 2016|Kidney disease         |Idaho               |190   |
# 2015|Suicide                |California          |4167  |
# 2015|Suicide                |Illinois            |1363  |
# 2016|Influenza and pneumonia|Arizona             |885   |
# 2015|Kidney disease         |Nevada              |316   |
# 2016|Suicide                |California          |4294  |
# 2016|Influenza and pneumonia|Delaware            |132   |
# 2016|Influenza and pneumonia|New Jersey          |1208  |
# 2015|Influenza and pneumonia|Washington          |851   |
# 2016|Suicide                |Illinois            |1415  |
# 2015|Kidney disease         |Florida             |3203  |
# 2015|Kidney disease         |Hawaii              |202   |
# 2015|Influenza and pneumonia|Minnesota           |738   |
# 2016|Influenza and pneumonia|Rhode Island        |165   |
# 2016|Influenza and pneumonia|Montana             |147   |
# 2016|Influenza and pneumonia|Texas               |2860  |
# 2016|Kidney disease         |Hawaii              |215   |
# 2015|Kidney disease         |Nebraska            |264   |
# 2016|Suicide                |Rhode Island        |126   |
# 2015|Suicide                |Rhode Island        |127   |
# 2016|Influenza and pneumonia|Idaho               |207   |
# 2016|Kidney disease         |Montana             |155   |
# 2016|Kidney disease         |North Dakota        |106   |
# 2015|Kidney disease         |Maine               |211   |
# 2015|Kidney disease         |New Hampshire       |194   |
# 2016|Influenza and pneumonia|District of Columbia|78    |
# 2016|Suicide                |Delaware            |119   |
# 2016|Influenza and pneumonia|Iowa                |504   |
# 2016|Influenza and pneumonia|Connecticut         |572   |
# 2016|Kidney disease         |New Mexico          |293   |
# 2015|Suicide                |Nebraska            |223   |
# 2016|Influenza and pneumonia|New Hampshire       |203   |
# 2016|Influenza and pneumonia|Wisconsin           |888   |
# 2016|Influenza and pneumonia|Maine               |231   |
# 2016|Influenza and pneumonia|South Carolina      |690   |
# 2016|Kidney disease         |Connecticut         |570   |
# 2015|Kidney disease         |Connecticut         |584   |
# 2016|Kidney disease         |Maryland            |823   |
# 2016|Suicide                |Hawaii              |174   |
# 2015|Influenza and pneumonia|Colorado            |659   |
# 2015|Kidney disease         |Maryland            |834   |
# 2015|Influenza and pneumonia|Idaho               |218   |
# 2016|Influenza and pneumonia|Oklahoma            |546   |
# 2016|Kidney disease         |Maine               |239   |
# 2016|Influenza and pneumonia|Alaska              |61    |
# 2015|Influenza and pneumonia|New Jersey          |1402  |
# 2015|Kidney disease         |North Dakota        |118   |
# 2015|Suicide                |Texas               |3403  |
# 2015|Alzheimer&apos;s disease    |New York            |3174  |
# 2016|Influenza and pneumonia|Indiana             |962   |
# 2015|Suicide                |Delaware            |122   |
# 2016|Suicide                |Texas               |3488  |
# 2016|Influenza and pneumonia|Virginia            |1177  |
# 2015|Suicide                |Georgia             |1317  |
# 2016|Suicide                |Mississippi         |383   |
# 2015|Suicide                |Virginia            |1118  |
# 2015|Kidney disease         |New Mexico          |316   |
# 2016|Kidney disease         |Oklahoma            |577   |
# 2015|Influenza and pneumonia|Texas               |3214  |
# 2016|Kidney disease         |Wisconsin           |960   |
# 2016|Suicide                |North Carolina      |1373  |
# 2016|Alzheimer&apos;s disease    |New York            |3349  |
# 2016|Suicide                |Nebraska            |246   |
# 2016|Kidney disease         |Massachusetts       |1139  |
# 2016|Suicide                |Minnesota           |745   |
# 2015|Suicide                |Minnesota           |730   |
# 2016|Suicide                |Virginia            |1166  |
# 2015|Kidney disease         |Wyoming             |86    |
# 2016|Suicide                |Georgia             |1409  |
# 2016|Suicide                |Michigan            |1364  |
# 2015|Diabetes               |Nevada              |420   |
# 2015|Suicide                |North Carolina      |1406  |
# 2015|Suicide                |Hawaii              |201   |
# 2015

# %%
d3.createOrReplaceTempView("NoOfDeathsUS")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dsql=spark.sql("SELECT State, Year, sum(Deaths) as TotalnumberOfDeaths from NoOfDeathsUS GROUP BY State, Year") 
dsql.show(dsql.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----+-------------------+
# State               |Year|TotalnumberOfDeaths|
# +--------------------+----+-------------------+
# Maryland            |2016|34323              |
# Hawaii              |2016|8109               |
# Nevada              |2015|17962              |
# Alaska              |2016|3241               |
# Alaska              |2015|3100               |
# Rhode Island        |2015|7394               |
# Louisiana           |2016|33414              |
# Tennessee           |2015|50304              |
# New Hampshire       |2016|8958               |
# New Mexico          |2016|13241              |
# Indiana             |2016|46203              |
# Kansas              |2016|18768              |
# Kansas              |2015|19061              |
# Missouri            |2015|45567              |
# Arkansas            |2016|24413              |
# Delaware            |2016|6655               |
# Massachusetts       |2016|39608              |
# Mississippi         |2015|24373              |
# Alabama             |2015|38527              |
# Arizona             |2016|41949              |
# Vermont             |2015|4404               |
# Wisconsin           |2015|37960              |
# Utah                |2016|12677              |
# Texas               |2015|138204             |
# South Dakota        |2015|5873               |
# South Carolina      |2016|35312              |
# Mississippi         |2016|24557              |
# Massachusetts       |2015|39963              |
# Oklahoma            |2016|30497              |
# Oregon              |2016|25822              |
# Utah                |2015|12486              |
# New Jersey          |2016|53092              |
# North Dakota        |2015|4655               |
# Minnesota           |2016|30291              |
# Michigan            |2015|72434              |
# New York            |2015|115452             |
# New Jersey          |2015|52716              |
# New Hampshire       |2015|8758               |
# Wisconsin           |2016|38276              |
# New Mexico          |2015|12653              |
# Ohio                |2016|88675              |
# West Virginia       |2015|16687              |
# Virginia            |2015|47512              |
# Arizona             |2015|40509              |
# Connecticut         |2016|21692              |
# Delaware            |2015|6339               |
# District of Columbia|2016|3646               |
# Hawaii              |2015|8315               |
# Missouri            |2016|45506              |
# North Dakota        |2016|4499               |
# Florida             |2016|148342             |
# Pennsylvania        |2015|97317              |
# Pennsylvania        |2016|97164              |
# Oklahoma            |2015|30880              |
# California          |2016|202300             |
# Wyoming             |2015|3556               |
# Iowa                |2016|21940              |
# Colorado            |2015|26480              |
# Maine               |2015|10580              |
# Alabama             |2016|38776              |
# Washington          |2015|40524              |
# Rhode Island        |2016|7039               |
# Indiana             |2015|45885              |
# Ohio                |2015|87860              |
# New York            |2016|115880             |
# Nevada              |2016|18697              |
# Vermont             |2016|4379               |
# Montana             |2015|7182               |
# Michigan            |2016|73681              |
# North Carolina      |2016|65751              |
# Nebraska            |2016|11418              |
# Kentucky            |2015|34625              |
# Connecticut         |2015|21681              |
# Arkansas            |2015|24453              |
# North Carolina      |2015|64932              |
# South Carolina      |2015|34563              |
# Minnesota           |2015|30049              |
# Georgia             |2016|60137              |
# Tennessee           |2016|50870              |
# South Dakota        |2016|5924               |
# Iowa                |2015|22095              |
# Maryland            |2015|33433              |
# Maine               |2016|10418              |
# California          |2015|199970             |
# Oregon              |2015|25367              |
# Virginia            |2016|47952              |
# Colorado            |2016|27552              |
# Washington          |2016|40352              |
# Georgia             |2015|58589              |
# Idaho               |2016|9979               |
# Idaho               |2015|9590               |
# Montana             |2016|7151               |
# Illinois            |2015|79220              |
# Kentucky            |2016|35504              |
# Illinois            |2016|78969              |
# District of Columbia|2015|3437               |
# Texas               |2016|140361             |
# Nebraska            |2015|11889              |
# Louisiana           |2015|32950              |
# Florida             |2015|144702             |
# Wyoming             |2016|3478               |
# West Virginia       |2016|16681              |
# +--------------------+----+-------------------+
#
# </div>

# %%
#Sum total number of deaths in USA 
d4=d3.filter(d3.Year == "2016").groupBy("State").sum("Deaths")
d4.show(d4.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----------+
# State               |sum(Deaths)|
# +--------------------+-----------+
# Utah                |12677      |
# Hawaii              |8109       |
# Minnesota           |30291      |
# Ohio                |88675      |
# Oregon              |25822      |
# Arkansas            |24413      |
# Texas               |140361     |
# North Dakota        |4499       |
# Pennsylvania        |97164      |
# Connecticut         |21692      |
# Vermont             |4379       |
# Nebraska            |11418      |
# Nevada              |18697      |
# Washington          |40352      |
# Illinois            |78969      |
# Oklahoma            |30497      |
# District of Columbia|3646       |
# Delaware            |6655       |
# Alaska              |3241       |
# New Mexico          |13241      |
# West Virginia       |16681      |
# Missouri            |45506      |
# Rhode Island        |7039       |
# Georgia             |60137      |
# Montana             |7151       |
# Virginia            |47952      |
# Michigan            |73681      |
# North Carolina      |65751      |
# Wyoming             |3478       |
# Kansas              |18768      |
# New Jersey          |53092      |
# Maryland            |34323      |
# Alabama             |38776      |
# Arizona             |41949      |
# Iowa                |21940      |
# Massachusetts       |39608      |
# Kentucky            |35504      |
# Louisiana           |33414      |
# Mississippi         |24557      |
# New Hampshire       |8958       |
# Tennessee           |50870      |
# Florida             |148342     |
# Indiana             |46203      |
# Idaho               |9979       |
# South Carolina      |35312      |
# South Dakota        |5924       |
# California          |202300     |
# New York            |115880     |
# Wisconsin           |38276      |
# Colorado            |27552      |
# Maine               |10418      |
# +--------------------+-----------+
#
# </div>

# %%
d3.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------------+--------------------+------+
# Year|          Cause Name|               State|Deaths|
# +----+--------------------+--------------------+------+
# 2016|      Kidney disease|             Vermont|    30|
# 2015|      Kidney disease|             Vermont|    39|
# 2015|             Suicide|District of Columbia|    34|
# 2016|             Suicide|District of Columbia|    40|
# 2015|      Kidney disease|             Arizona|   458|
# 2016|      Kidney disease|             Arizona|   487|
# 2015|      Kidney disease|          Washington|   474|
# 2016|      Kidney disease|          Washington|   532|
# 2016|Influenza and pne...|             Vermont|    59|
# 2016|             Suicide|          New Jersey|   687|
# 2015|      Kidney disease|        South Dakota|    79|
# 2016|      Kidney disease|        South Dakota|    90|
# 2016|      Kidney disease|              Oregon|   398|
# 2016|Influenza and pne...|           Minnesota|   529|
# 2015|             Suicide|            New York|  1652|
# 2015|      Kidney disease|                Iowa|   336|
# 2016|             Suicide|            New York|  1679|
# 2015|      Kidney disease|              Oregon|   409|
# 2016|      Kidney disease|                Iowa|   352|
# 2015|             Suicide|          New Jersey|   789|
# +----+--------------------+--------------------+------+
# only showing top 20 rows
#
# </div>

# %%
d5=d3.groupBy("Year").sum("Deaths") 
d5.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----------+
# Year|sum(Deaths)|
# +----+-----------+
# 2015|    2013017|
# 2016|    2034119|
# +----+-----------+
#
# </div>

# %%
d6 = d3.select("Year", "Cause Name", "State", "Deaths")
d6.show(d6.count(), False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----------------------+--------------------+------+
# Year|Cause Name             |State               |Deaths|
# +----+-----------------------+--------------------+------+
# 2016|Kidney disease         |Vermont             |30    |
# 2015|Kidney disease         |Vermont             |39    |
# 2015|Suicide                |District of Columbia|34    |
# 2016|Suicide                |District of Columbia|40    |
# 2015|Kidney disease         |Arizona             |458   |
# 2016|Kidney disease         |Arizona             |487   |
# 2015|Kidney disease         |Washington          |474   |
# 2016|Kidney disease         |Washington          |532   |
# 2016|Influenza and pneumonia|Vermont             |59    |
# 2016|Suicide                |New Jersey          |687   |
# 2015|Kidney disease         |South Dakota        |79    |
# 2016|Kidney disease         |South Dakota        |90    |
# 2016|Kidney disease         |Oregon              |398   |
# 2016|Influenza and pneumonia|Minnesota           |529   |
# 2015|Suicide                |New York            |1652  |
# 2015|Kidney disease         |Iowa                |336   |
# 2016|Suicide                |New York            |1679  |
# 2015|Kidney disease         |Oregon              |409   |
# 2016|Kidney disease         |Iowa                |352   |
# 2015|Suicide                |New Jersey          |789   |
# 2015|Influenza and pneumonia|Alaska              |41    |
# 2015|Kidney disease         |Colorado            |458   |
# 2016|Kidney disease         |California          |3640  |
# 2015|Kidney disease         |California          |3557  |
# 2015|Kidney disease         |Idaho               |154   |
# 2016|Kidney disease         |Minnesota           |588   |
# 2016|Kidney disease         |Nevada              |274   |
# 2015|Suicide                |Maryland            |553   |
# 2016|Suicide                |Massachusetts       |631   |
# 2015|Influenza and pneumonia|Florida             |2676  |
# 2016|Influenza and pneumonia|Oregon              |452   |
# 2016|Kidney disease         |Colorado            |491   |
# 2015|Suicide                |Massachusetts       |642   |
# 2015|Influenza and pneumonia|Oregon              |453   |
# 2016|Kidney disease         |District of Columbia|57    |
# 2016|Influenza and pneumonia|Florida             |2808  |
# 2015|Kidney disease         |Montana             |121   |
# 2015|Kidney disease         |New York            |2245  |
# 2016|Kidney disease         |New Hampshire       |161   |
# 2016|Suicide                |Maryland            |586   |
# 2015|Influenza and pneumonia|Arizona             |775   |
# 2016|Kidney disease         |Nebraska            |220   |
# 2016|Influenza and pneumonia|Colorado            |533   |
# 2015|Kidney disease         |Minnesota           |639   |
# 2016|Kidney disease         |New York            |2385  |
# 2015|Kidney disease         |Rhode Island        |142   |
# 2015|Kidney disease         |District of Columbia|65    |
# 2016|Kidney disease         |Rhode Island        |141   |
# 2015|Suicide                |Connecticut         |384   |
# 2015|Influenza and pneumonia|Vermont             |85    |
# 2016|Influenza and pneumonia|Washington          |815   |
# 2016|Kidney disease         |Alaska              |53    |
# 2015|Kidney disease         |Alaska              |50    |
# 2016|Kidney disease         |Wyoming             |66    |
# 2016|Suicide                |Connecticut         |397   |
# 2016|Kidney disease         |Florida             |3144  |
# 2016|Kidney disease         |Idaho               |190   |
# 2015|Suicide                |California          |4167  |
# 2015|Suicide                |Illinois            |1363  |
# 2016|Influenza and pneumonia|Arizona             |885   |
# 2015|Kidney disease         |Nevada              |316   |
# 2016|Suicide                |California          |4294  |
# 2016|Influenza and pneumonia|Delaware            |132   |
# 2016|Influenza and pneumonia|New Jersey          |1208  |
# 2015|Influenza and pneumonia|Washington          |851   |
# 2016|Suicide                |Illinois            |1415  |
# 2015|Kidney disease         |Florida             |3203  |
# 2015|Kidney disease         |Hawaii              |202   |
# 2015|Influenza and pneumonia|Minnesota           |738   |
# 2016|Influenza and pneumonia|Rhode Island        |165   |
# 2016|Influenza and pneumonia|Montana             |147   |
# 2016|Influenza and pneumonia|Texas               |2860  |
# 2016|Kidney disease         |Hawaii              |215   |
# 2015|Kidney disease         |Nebraska            |264   |
# 2016|Suicide                |Rhode Island        |126   |
# 2015|Suicide                |Rhode Island        |127   |
# 2016|Influenza and pneumonia|Idaho               |207   |
# 2016|Kidney disease         |Montana             |155   |
# 2016|Kidney disease         |North Dakota        |106   |
# 2015|Kidney disease         |Maine               |211   |
# 2015|Kidney disease         |New Hampshire       |194   |
# 2016|Influenza and pneumonia|District of Columbia|78    |
# 2016|Suicide                |Delaware            |119   |
# 2016|Influenza and pneumonia|Iowa                |504   |
# 2016|Influenza and pneumonia|Connecticut         |572   |
# 2016|Kidney disease         |New Mexico          |293   |
# 2015|Suicide                |Nebraska            |223   |
# 2016|Influenza and pneumonia|New Hampshire       |203   |
# 2016|Influenza and pneumonia|Wisconsin           |888   |
# 2016|Influenza and pneumonia|Maine               |231   |
# 2016|Influenza and pneumonia|South Carolina      |690   |
# 2016|Kidney disease         |Connecticut         |570   |
# 2015|Kidney disease         |Connecticut         |584   |
# 2016|Kidney disease         |Maryland            |823   |
# 2016|Suicide                |Hawaii              |174   |
# 2015|Influenza and pneumonia|Colorado            |659   |
# 2015|Kidney disease         |Maryland            |834   |
# 2015|Influenza and pneumonia|Idaho               |218   |
# 2016|Influenza and pneumonia|Oklahoma            |546   |
# 2016|Kidney disease         |Maine               |239   |
# 2016|Influenza and pneumonia|Alaska              |61    |
# 2015|Influenza and pneumonia|New Jersey          |1402  |
# 2015|Kidney disease         |North Dakota        |118   |
# 2015|Suicide                |Texas               |3403  |
# 2015|Alzheimer&apos;s disease    |New York            |3174  |
# 2016|Influenza and pneumonia|Indiana             |962   |
# 2015|Suicide                |Delaware            |122   |
# 2016|Suicide                |Texas               |3488  |
# 2016|Influenza and pneumonia|Virginia            |1177  |
# 2015|Suicide                |Georgia             |1317  |
# 2016|Suicide                |Mississippi         |383   |
# 2015|Suicide                |Virginia            |1118  |
# 2015|Kidney disease         |New Mexico          |316   |
# 2016|Kidney disease         |Oklahoma            |577   |
# 2015|Influenza and pneumonia|Texas               |3214  |
# 2016|Kidney disease         |Wisconsin           |960   |
# 2016|Suicide                |North Carolina      |1373  |
# 2016|Alzheimer&apos;s disease    |New York            |3349  |
# 2016|Suicide                |Nebraska            |246   |
# 2016|Kidney disease         |Massachusetts       |1139  |
# 2016|Suicide                |Minnesota           |745   |
# 2015|Suicide                |Minnesota           |730   |
# 2016|Suicide                |Virginia            |1166  |
# 2015|Kidney disease         |Wyoming             |86    |
# 2016|Suicide                |Georgia             |1409  |
# 2016|Suicide                |Michigan            |1364  |
# 2015|Diabetes               |Nevada              |420   |
# 2015|Suicide                |North Carolina      |1406  |
# 2015|Suicide                |Hawaii              |201   |
# 2015

# %%
#save file as csv.
DF12.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("/FileStore/Project/UnhealthyBehaviours.csv")
